# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}
df = pd.DataFrame(data)
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    811     86   John  January      Q1
# 1  2023-01-02       B   West    689     25   Mary  January      Q1
# 2  2023-01-03       C  North    477     20    Bob  January      Q1
# 3  2023-01-04       D  South    578     49  Alice  January      Q1
# 4  2023-01-05       A   East    570     80   John  January      Q1
# 5  2023-01-06       B   West    664     23   Mary  January      Q1
# 6  2023-01-07       C  North    604     42    Bob  January      Q1
# 7  2023-01-08       D  South    793     19  Alice  January      Q1
# 8  2023-01-09       A   East    128     29   John  January      Q1
# 9  2023-01-10       B   West    211     66   Mary  January      Q1
# 10 2023-01-11       C  North    302     63    Bob  January      Q1
# 11 2023-01-12       D  South    910     58  Alice  January      Q1
# 12 2023-01-13       A   East    556     40   John  January      Q1
# 13 2023-01-14       B   West    755     21   Mary  January      Q1
# 14 2023-01-15       C  North    684     60    Bob  January      Q1
# 15 2023-01-16       D  South    317     54  Alice  January      Q1
# 16 2023-01-17       A   East    898     55   John  January      Q1
# 17 2023-01-18       B   West    735     51   Mary  January      Q1
# 18 2023-01-19       C  North    842     67    Bob  January      Q1
# 19 2023-01-20       D  South    519     30  Alice  January      Q1

# %%
pivot1 = pd.pivot_table(df,values="Sales",index="Region",columns="Product")
pivot1
# Out:
# Product      A      B      C      D
# Region
# East     592.6    NaN    NaN    NaN
# North      NaN    NaN  581.8    NaN
# South      NaN    NaN    NaN  623.4
# West       NaN  610.8    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,values=["Units","Sales"],index="Region",columns="Product")
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     592.6    NaN    NaN    NaN  58.0   NaN   NaN   NaN
# North      NaN    NaN  581.8    NaN   NaN   NaN  50.4   NaN
# South      NaN    NaN    NaN  623.4   NaN   NaN   NaN  42.0
# West       NaN  610.8    NaN    NaN   NaN  37.2   NaN   NaN

# %%
#CrossTabs

# %%
pd.crosstab(df["Region"],df["Product"])#counts
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
